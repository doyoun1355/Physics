# %% [markdown]
# <a href="https://colab.research.google.com/github/doyoun1355/Physics/blob/20250525/5_1%EC%9E%A5_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_2025_05_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 예제 5 - 1
import math

m = 0.15
r = 0.60
f = 2.0
pi = math.pi

# (a)
T = 1/f

# (b)
v = 2 * pi * r / T

# (c)
ac = v * v / r

print(f"{T:.2f}s")
print(f"{v:.2f}m/s")
print(f"{ac:.2f}m/s²")
# Out:
# 0.50s
# 7.54m/s
# 94.75m/s

# %%
# 관련 예제
ac = g = 9.8

print(f"{ac:.2f}m/s²")
# Out:
# 9.80m/s²

# %%
# 예제 5 - 3

r = 500
v0 = 0
v = 32
T = 10.5
vr = 35

# (a)
at = (v - v0) / T

# (b)
ar = v * v / r

print(f"{at:.2f} m/s²")
print(f"{ac:.2f} m/s²")
# Out:
# 3.05 m/s²
# 9.80 m/s²
